# %%
row = 5

# %%
for i in range(1, row +1):
  for j in range(row-i):
    print(" ", end="")
  for m in range(i):
    print("* ", end="")
  print()
# Out:
#     *
#    * *
#   * * *
#  * * * *
# * * * * *
