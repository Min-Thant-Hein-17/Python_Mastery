# %%
#Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import KNNImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, accuracy_score, precision_score, recall_score, confusion_matrix

# %%
pip install --upgrade stellar-sdk
# Out:
# Collecting stellar-sdk
#   Using cached stellar_sdk-13.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting mnemonic>=0.20 (from stellar-sdk)
#   Using cached mnemonic-0.21-py3-none-any.whl.metadata (3.4 kB)
# Collecting pydantic>=2.0.0 (from stellar-sdk)
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting pynacl>=1.4.0 (from stellar-sdk)
#   Using cached pynacl-1.6.2-cp38-abi3-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: requests>=2.0.0 in d:\advancedml\myvenv\lib\site-packages (from stellar-sdk) (2.32.5)
# Collecting requests-sse>=0.3 (from stellar-sdk)
#   Using cached requests_sse-0.5.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in d:\advancedml\myvenv\lib\site-packages (from stellar-sdk) (4.15.0)
# Collecting xdrlib3>=0.1.1 (from stellar-sdk)
#   Using cached xdrlib3-0.1.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.0.0->stellar-sdk)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic>=2.0.0->stellar-sdk)
#   Using cached pydantic_core-2.41.5-cp312-cp312-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic>=2.0.0->stellar-sdk)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting cffi>=2.0.0 (from pynacl>=1.4.0->stellar-sdk)
#   Using cached cffi-2.0.0-cp312-cp312-win_amd64.whl.metadata (2.6 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\advancedml\myvenv\lib\site-packages (from requests>=2.0.0->stellar-sdk) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\advancedml\myvenv\lib\site-packages (from requests>=2.0.0->stellar-sdk) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\advancedml\myvenv\lib\site-packages (from requests>=2.0.0->stellar-sdk) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\advancedml\myvenv\lib\site-packages (from requests>=2.0.0->stellar-sdk) (2025.10.5)
# Collecting pycparser (from cffi>=2.0.0->pynacl>=1.4.0->stellar-sdk)
#   Using cached pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# Using cached stellar_sdk-13.2.1-py3-none-any.whl (770 kB)
# Using cached mnemonic-0.21-py3-none-any.whl (92 kB)
# Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# Using cached pydantic_core-2.41.5-cp312-cp312-win_amd64.whl (2.0 MB)
# Using cached pynacl-1.6.2-cp38-abi3-win_amd64.whl (239 kB)
# Using cached requests_sse-0.5.2-py3-none-any.whl (10 kB)
# Using cached xdrlib3-0.1.1-py3-none-any.whl (3.7 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached cffi-2.0.0-cp312-cp312-win_amd64.whl (183 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached pycparser-3.0-py3-none-any.whl (48 kB)
# Installing collected packages: xdrlib3, typing-inspection, pydantic-core, pycparser, mnemonic, annotated-types, requests-sse, pydantic, cffi, pynacl, stellar-sdk
# Successfully installed annotated-types-0.7.0 cffi-2.0.0 mnemonic-0.21 pycparser-3.0 pydantic-2.12.5 pydantic-core-2.41.5 pynacl-1.6.2 requests-sse-0.5.2 stellar-sdk-13.2.1 typing-inspection-0.4.2 xdrlib3-0.1.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from stellar_sdk import Server, Keypair, TransactionBuilder, Network, Asset

# %%
server = Server("https://horizon-testnet.stellar.org")

# %%
account_id = "GB4ROAY34R7AOCFH2C5E7UT5DI2GKBJV5Z5Q3JA24IHFL5W3SKB323JH"

# %%
import os
import csv
from datetime import datetime, timedelta
from collections import defaultdict

import pandas as pd
